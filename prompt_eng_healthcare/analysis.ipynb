# %%
import pandas as pd

# %%
df = pd.read_csv("evaluationscores.csv")

# %%
df.set_index("Prompt_Type").mean(axis=1).sort_values(ascending=False)
# Out:
# Prompt_Type
# Structured    4.2
# Role-Based    3.4
# Basic         2.6
# dtype: float64

# %%
df.columns
# Out:
# Index(['Prompt_Type', 'Accuracy', 'Hallucination_Control', 'Clarity',
#        'Clinical_Relevance', 'Actionability'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt

df.set_index("Prompt_Type").mean(axis=1).plot(kind="bar")
plt.ylabel("Average Score")
plt.title("Prompt Comparison")
plt.show()
